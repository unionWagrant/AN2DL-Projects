# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive
# Out:
# Mounted at /gdrive
# /gdrive/My Drive

# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Import other libraries
import cv2
from tensorflow.keras.applications.mobilenet import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
# Out:
# 2.14.0

# %%
# Conditional check for unzipping
unzip = True  # Set this flag to True to unzip the file

# Unzip the 'public_data.zip' file if the 'unzip' flag is True
if unzip:
    # !unzip public_data.zip
    data = np.load('public_data.npz', allow_pickle=True)

image_data=data['data']
image_labels=data['labels']
# Out:
# Archive:  public_data.zip
# replace public_data.npz? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
def preprocess_image(data):
    images=[]
    image_data=data['data']
    image_labels=data['labels']
    # Iterate through files in the specified folder
    for image in image_data:

        # Normalize image pixel values to a float range [0, 1]
        image = (image / 255).astype(np.float32)

        # Resize the image to 32x32 pixels
        #image = tfkl.Resizing(128, 128)(image)

        if image is not None:
            images.append(image)


    labels = np.where(image_labels == 'healthy', 0, 1)



    return np.array(images),labels


images,labels=preprocess_image(data)

# %%
def filter_images_by_intensity(images, labels, thresholds):
    # Calculate the average intensity for each image
    filtered_images=[]
    filtered_image_index=[]
    for i in range(len(images)):
      average_intensity = np.mean(images[i])
      mask1 = (thresholds[0] <= average_intensity) & (average_intensity <= thresholds[1])  #shrek images
      mask2 = (thresholds[2] <= average_intensity) & (average_intensity <= thresholds[3])  #trololo images

      if mask1 or mask2:
        filtered_images.append(images[i])
        filtered_image_index.append(i)

      # Use boolean indexing to filter out elements
    filtered_images = np.delete(images, filtered_image_index, axis=0)
    filtered_labels = np.delete(labels, filtered_image_index, axis=0)

    return filtered_images,filtered_labels

thresholds = [0.25200000, 0.2540000000, 0.4440000000000, 0.4450000000]

filtered_images,filtered_labels = filter_images_by_intensity(images, labels, thresholds)

# %%
# Display a sample of images from the training-validation dataset
num_img = 10
z=30
fig, axes = plt.subplots(1, num_img, figsize=(20, 20))

# Iterate through the selected number of images
for i in range(num_img):
    ax = axes[i%num_img]
    ax.imshow(filtered_images[i+z], cmap='gray')
    ax.set_title(f'{i+z}')  # Show the corresponding digit label

# Adjust layout and display the images
plt.tight_layout()
plt.show()

# %%
# Split the data into training (90%) and temporary data (10%)
X_train_val, X_test, Y_train_val, Y_test = train_test_split(filtered_images, filtered_labels, test_size=0.1, random_state=seed)

# Now, split the combined training and validation data into training (90%) and validation (10%)
X_train, X_val, Y_train, Y_val = train_test_split(X_train_val, Y_train_val, test_size=0.1, random_state=seed, stratify=Y_train_val)


# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {Y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {Y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {Y_test.shape}")
# Out:
# X_train shape: (4041, 96, 96, 3), y_train shape: (4041,)
# X_val shape: (450, 96, 96, 3), y_val shape: (450,)
# X_test shape: (499, 96, 96, 3), y_test shape: (499,)

# %%
# Display the count of occurrences of target classes in the training-validation dataset
print('Counting occurrences of target classes:')
print(pd.DataFrame(Y_train_val, columns=['class'])['class'].value_counts())
# Out:
# Counting occurrences of target classes:
# 0    2808
# 1    1683
# Name: class, dtype: int64

# %%
# Define batch size, number of epochs, learning rate, input shape, and output shape
batch_size = 64
epochs = 100
learning_rate = 1e-4
input_shape = X_train.shape[1:]
output_shape = 1

# Print batch size, epochs, learning rate, input shape, and output shape
print(f"Batch Size: {batch_size}, Epochs: {epochs}, Learning Rate: {learning_rate}")
print(f"Input Shape: {input_shape}, Output Shape: {output_shape}")
# Out:
# Batch Size: 64, Epochs: 100, Learning Rate: 0.0001
# Input Shape: (96, 96, 3), Output Shape: 1

# %%
# Define two callback functions for early stopping and learning rate reduction
# Define two callback functions for early stopping and learning rate reduction
callbacks=[
    tfk.callbacks.EarlyStopping(monitor='val_accuracy', patience=25, restore_best_weights=True, mode='max'),
    tfk.callbacks.ReduceLROnPlateau(monitor="val_accuracy", factor=0.1, patience=20, min_lr=1e-5, mode='max')
]

# Print the defined callbacks
print("Callbacks:")
for callback in callbacks:
    print(callback)
# Out:
# Callbacks:
# <keras.src.callbacks.EarlyStopping object at 0x793050597010>
# <keras.src.callbacks.ReduceLROnPlateau object at 0x793050597700>

# %%
def VGG16(input_shape, seed=seed):
    tf.random.set_seed(seed)

    preprocessing = tf.keras.Sequential([
        tfkl.RandomBrightness(0.2, value_range=(0,1)),
        tfkl.RandomTranslation(0.2,0.2),
    ], name='preprocessing')

    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    preprocessing = preprocessing(input_layer)

    x = tfkl.Conv2D(64, (3, 3), padding='same')(preprocessing)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.Conv2D(64, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.MaxPooling2D((2, 2), strides=(2, 2))(x)

    # Block 2
    x = tfkl.Conv2D(128, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.Conv2D(128, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.MaxPooling2D((2, 2), strides=(2, 2))(x)

    # Block 3
    x = tfkl.Conv2D(256, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.Conv2D(256, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.Conv2D(256, (3, 3), padding='same')(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)

    x = tfkl.MaxPooling2D((2, 2), strides=(2, 2))(x)

    # Flatten the results to feed into a DNN
    x = tfkl.Flatten()(x)

    # 512 neuron hidden layer with dropout
    x = tfkl.Dense(512)(x)
    x = tfkl.BatchNormalization()(x)
    x = tfkl.Activation('relu')(x)
    x = tfkl.Dropout(0.5)(x)

    # Only 1 output neuron. It will contain a value from 0-1 where 0 for one class and 1 for the other class
    output_layer = tfkl.Dense(1, activation='sigmoid')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='VGG16-like_with_dropout')

    # Compile the model with RMSprop optimizer and binary crossentropy loss
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=tf.keras.optimizers.AdamW(learning_rate, weight_decay=5e-4), metrics=['accuracy'])

    # Return the model
    return model

# %%
model = VGG16(input_shape)
model.summary()
# Out:
# Model: "VGG16-like_with_dropout"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  conv2d_28 (Conv2D)          (None, 96, 96, 64)        1792
#
#  batch_normalization_16 (Ba  (None, 96, 96, 64)        256
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 96, 96, 64)        0
#
#  conv2d_29 (Conv2D)          (None, 96, 96, 64)        36928
#
#  batch_normalization_17 (Ba  (None, 96, 96, 64)        256
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 96, 96, 64)        0
#
#  max_pooling2d_12 (MaxPooli  (None, 48, 48, 64)        0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 48, 48, 128)       73856
#
#  batch_normalization_18 (Ba  (None, 48, 48, 128)       512
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 48, 48, 128)       0
#
#  conv2d_31 (Conv2D)          (None, 48, 48, 128)       147584
#
#  batch_normalization_19 (Ba  (None, 48, 48, 128)       512
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 48, 48, 128)       0
#
#  max_pooling2d_13 (MaxPooli  (None, 24, 24, 128)       0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 24, 24, 256)       295168
#
#  batch_normalization_20 (Ba  (None, 24, 24, 256)       1024
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 24, 24, 256)       0
#
#  conv2d_33 (Conv2D)          (None, 24, 24, 256)       590080
#
#  batch_normalization_21 (Ba  (None, 24, 24, 256)       1024
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 24, 24, 256)       0
#
#  conv2d_34 (Conv2D)          (None, 24, 24, 256)       590080
#
#  batch_normalization_22 (Ba  (None, 24, 24, 256)       1024
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 24, 24, 256)       0
#
#  max_pooling2d_14 (MaxPooli  (None, 12, 12, 256)       0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 36864)             0
#
#  dense_8 (Dense)             (None, 512)               18874880
#
#  batch_normalization_23 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 512)               0
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20617537 (78.65 MB)
# Trainable params: 20614209 (78.64 MB)
# Non-trainable params: 3328 (13.00 KB)
# _________________________________________________________________

# %%
# Define the number of folds
k_folds = 5

# Create a StratifiedKFold object
stratified_kfold = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=seed)

# Initialize a list to store the performance metrics for each fold
fold_accuracies = []

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(stratified_kfold.split(X_train, Y_train)):
    print(f'\nTraining on Fold {fold + 1}/{k_folds}...')

    # Split the data into training and validation sets for this fold
    X_fold_train, Y_fold_train = X_train[train_indices], Y_train[train_indices]
    X_fold_val, Y_fold_val = X_train[val_indices], Y_train[val_indices]

    # Build the model
    model = VGG16(input_shape)

    # Compile the model with AdamW optimizer and binary crossentropy loss
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=tf.keras.optimizers.AdamW(learning_rate, weight_decay=5e-4), metrics=['accuracy'])

    # Train the model on the current fold
    history = model.fit(
        X_fold_train,
        Y_fold_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(X_fold_val, Y_fold_val),
        verbose=1
    )

    # Evaluate the model on the validation set of the current fold
    _, accuracy = model.evaluate(X_fold_val, Y_fold_val, verbose=0)
    print(f'Accuracy on Fold {fold + 1}: {accuracy * 100:.2f}%')

    # Save the accuracy for later analysis
    fold_accuracies.append(accuracy)

# Calculate and print the average accuracy across all folds
average_accuracy = np.mean(fold_accuracies)
print(f'\nAverage Accuracy Across {k_folds} Folds: {average_accuracy * 100:.2f}%')
# Out:
# Training on Fold 1/5...
# Epoch 1/100
# 51/51 [==============================] - 20s 238ms/step - loss: 0.8837 - accuracy: 0.5897 - val_loss: 0.9192 - val_accuracy: 0.6255
# Epoch 2/100
# 51/51 [==============================] - 9s 183ms/step - loss: 0.7226 - accuracy: 0.6535 - val_loss: 1.4466 - val_accuracy: 0.6255
# Epoch 3/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.6583 - accuracy: 0.6819 - val_loss: 2.8191 - val_accuracy: 0.6255
# Epoch 4/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.6287 - accuracy: 0.6918 - val_loss: 3.1119 - val_accuracy: 0.6255
# Epoch 5/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.5789 - accuracy: 0.7184 - val_loss: 3.4843 - val_accuracy: 0.6255
# Epoch 6/100
# 51/51 [==============================] - 8s 166ms/step - loss: 0.5743 - accuracy: 0.7302 - val_loss: 4.4238 - val_accuracy: 0.6255
# Epoch 7/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.6058 - accuracy: 0.7110 - val_loss: 3.3992 - val_accuracy: 0.6255
# Epoch 8/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.5643 - accuracy: 0.7305 - val_loss: 3.2835 - val_accuracy: 0.6255
# Epoch 9/100
# 51/51 [==============================] - 10s 193ms/step - loss: 0.5494 - accuracy: 0.7460 - val_loss: 2.3847 - val_accuracy: 0.6267
# Epoch 10/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.5291 - accuracy: 0.7519 - val_loss: 1.6825 - val_accuracy: 0.6354
# Epoch 11/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.5508 - accuracy: 0.7423 - val_loss: 1.1608 - val_accuracy: 0.6440
# Epoch 12/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5185 - accuracy: 0.7540 - val_loss: 0.9010 - val_accuracy: 0.6934
# Epoch 13/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4865 - accuracy: 0.7788 - val_loss: 0.5368 - val_accuracy: 0.7701
# Epoch 14/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4987 - accuracy: 0.7769 - val_loss: 0.4597 - val_accuracy: 0.7862
# Epoch 15/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4704 - accuracy: 0.7902 - val_loss: 0.5121 - val_accuracy: 0.7664
# Epoch 16/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4610 - accuracy: 0.7908 - val_loss: 0.4889 - val_accuracy: 0.7899
# Epoch 17/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4437 - accuracy: 0.7970 - val_loss: 0.5911 - val_accuracy: 0.7441
# Epoch 18/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4621 - accuracy: 0.7921 - val_loss: 0.6491 - val_accuracy: 0.7478
# Epoch 19/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4422 - accuracy: 0.7970 - val_loss: 0.6091 - val_accuracy: 0.7404
# Epoch 20/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4118 - accuracy: 0.8144 - val_loss: 0.5052 - val_accuracy: 0.7948
# Epoch 21/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4114 - accuracy: 0.8277 - val_loss: 0.4418 - val_accuracy: 0.8133
# Epoch 22/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4150 - accuracy: 0.8110 - val_loss: 0.5530 - val_accuracy: 0.7750
# Epoch 23/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4205 - accuracy: 0.8097 - val_loss: 0.8095 - val_accuracy: 0.7009
# Epoch 24/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3942 - accuracy: 0.8239 - val_loss: 0.5556 - val_accuracy: 0.7577
# Epoch 25/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3981 - accuracy: 0.8233 - val_loss: 0.4565 - val_accuracy: 0.7960
# Epoch 26/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3744 - accuracy: 0.8295 - val_loss: 0.6485 - val_accuracy: 0.7454
# Epoch 27/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3690 - accuracy: 0.8422 - val_loss: 0.4648 - val_accuracy: 0.8072
# Epoch 28/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3620 - accuracy: 0.8394 - val_loss: 0.4485 - val_accuracy: 0.7985
# Epoch 29/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3836 - accuracy: 0.8258 - val_loss: 0.6235 - val_accuracy: 0.7590
# Epoch 30/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3460 - accuracy: 0.8521 - val_loss: 0.4215 - val_accuracy: 0.8096
# Epoch 31/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3272 - accuracy: 0.8555 - val_loss: 0.3914 - val_accuracy: 0.8319
# Epoch 32/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.3378 - accuracy: 0.8530 - val_loss: 0.7729 - val_accuracy: 0.7342
# Epoch 33/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3237 - accuracy: 0.8598 - val_loss: 0.6146 - val_accuracy: 0.7268
# Epoch 34/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3157 - accuracy: 0.8642 - val_loss: 0.3752 - val_accuracy: 0.8529
# Epoch 35/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3049 - accuracy: 0.8679 - val_loss: 0.5326 - val_accuracy: 0.7886
# Epoch 36/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.2947 - accuracy: 0.8762 - val_loss: 0.5737 - val_accuracy: 0.7763
# Epoch 37/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2834 - accuracy: 0.8759 - val_loss: 0.4786 - val_accuracy: 0.8158
# Epoch 38/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2967 - accuracy: 0.8784 - val_loss: 0.6848 - val_accuracy: 0.7392
# Epoch 39/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2860 - accuracy: 0.8834 - val_loss: 0.4071 - val_accuracy: 0.8282
# Epoch 40/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2766 - accuracy: 0.8858 - val_loss: 0.5026 - val_accuracy: 0.7862
# Epoch 41/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2741 - accuracy: 0.8809 - val_loss: 0.3640 - val_accuracy: 0.8443
# Epoch 42/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2497 - accuracy: 0.8936 - val_loss: 0.8043 - val_accuracy: 0.6650
# Epoch 43/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2578 - accuracy: 0.8948 - val_loss: 0.3824 - val_accuracy: 0.8566
# Epoch 44/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2594 - accuracy: 0.8945 - val_loss: 0.3468 - val_accuracy: 0.8418
# Epoch 45/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2568 - accuracy: 0.8960 - val_loss: 0.5545 - val_accuracy: 0.8121
# Epoch 46/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2446 - accuracy: 0.8970 - val_loss: 0.5610 - val_accuracy: 0.8059
# Epoch 47/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.2480 - accuracy: 0.8963 - val_loss: 0.4186 - val_accuracy: 0.8171
# Epoch 48/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2511 - accuracy: 0.8923 - val_loss: 0.5866 - val_accuracy: 0.7787
# Epoch 49/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2312 - accuracy: 0.9007 - val_loss: 0.3771 - val_accuracy: 0.8443
# Epoch 50/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2434 - accuracy: 0.9010 - val_loss: 0.9648 - val_accuracy: 0.6934
# Epoch 51/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.2151 - accuracy: 0.9118 - val_loss: 0.4344 - val_accuracy: 0.8269
# Epoch 52/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1974 - accuracy: 0.9196 - val_loss: 0.5646 - val_accuracy: 0.7936
# Epoch 53/100
# 51/51 [==============================] - 9s 183ms/step - loss: 0.2053 - accuracy: 0.9158 - val_loss: 1.0121 - val_accuracy: 0.7466
# Epoch 54/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2343 - accuracy: 0.8998 - val_loss: 0.5119 - val_accuracy: 0.7973
# Epoch 55/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2109 - accuracy: 0.9171 - val_loss: 0.3854 - val_accuracy: 0.8455
# Epoch 56/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1914 - accuracy: 0.9226 - val_loss: 0.4813 - val_accuracy: 0.8183
# Epoch 57/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2021 - accuracy: 0.9174 - val_loss: 0.9020 - val_accuracy: 0.7268
# Epoch 58/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1867 - accuracy: 0.9202 - val_loss: 0.3719 - val_accuracy: 0.8480
# Epoch 59/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1943 - accuracy: 0.9236 - val_loss: 0.3876 - val_accuracy: 0.8492
# Epoch 60/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1871 - accuracy: 0.9251 - val_loss: 0.5930 - val_accuracy: 0.7775
# Epoch 61/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1819 - accuracy: 0.9288 - val_loss: 0.3319 - val_accuracy: 0.8616
# Epoch 62/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1786 - accuracy: 0.9233 - val_loss: 0.4866 - val_accuracy: 0.7911
# Epoch 63/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1657 - accuracy: 0.9350 - val_loss: 0.5791 - val_accuracy: 0.8084
# Epoch 64/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1781 - accuracy: 0.9270 - val_loss: 0.4298 - val_accuracy: 0.8418
# Epoch 65/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1945 - accuracy: 0.9223 - val_loss: 0.6736 - val_accuracy: 0.8059
# Epoch 66/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1727 - accuracy: 0.9301 - val_loss: 0.3313 - val_accuracy: 0.8628
# Epoch 67/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1554 - accuracy: 0.9400 - val_loss: 0.3898 - val_accuracy: 0.8418
# Epoch 68/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1497 - accuracy: 0.9403 - val_loss: 0.3547 - val_accuracy: 0.8653
# Epoch 69/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1586 - accuracy: 0.9356 - val_loss: 0.5727 - val_accuracy: 0.7849
# Epoch 70/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1505 - accuracy: 0.9403 - val_loss: 0.5733 - val_accuracy: 0.8096
# Epoch 71/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1457 - accuracy: 0.9397 - val_loss: 0.9907 - val_accuracy: 0.6934
# Epoch 72/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1429 - accuracy: 0.9455 - val_loss: 0.7767 - val_accuracy: 0.7503
# Epoch 73/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1335 - accuracy: 0.9502 - val_loss: 1.0667 - val_accuracy: 0.7058
# Epoch 74/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1435 - accuracy: 0.9465 - val_loss: 0.3331 - val_accuracy: 0.8776
# Epoch 75/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1329 - accuracy: 0.9471 - val_loss: 0.4040 - val_accuracy: 0.8480
# Epoch 76/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1251 - accuracy: 0.9530 - val_loss: 0.3771 - val_accuracy: 0.8591
# Epoch 77/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1223 - accuracy: 0.9542 - val_loss: 0.4462 - val_accuracy: 0.8480
# Epoch 78/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1378 - accuracy: 0.9431 - val_loss: 0.3617 - val_accuracy: 0.8665
# Epoch 79/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1333 - accuracy: 0.9477 - val_loss: 0.4646 - val_accuracy: 0.8381
# Epoch 80/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1295 - accuracy: 0.9536 - val_loss: 0.4699 - val_accuracy: 0.8455
# Epoch 81/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1211 - accuracy: 0.9539 - val_loss: 0.5199 - val_accuracy: 0.8282
# Epoch 82/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1381 - accuracy: 0.9477 - val_loss: 0.3750 - val_accuracy: 0.8517
# Epoch 83/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1257 - accuracy: 0.9527 - val_loss: 1.2203 - val_accuracy: 0.6959
# Epoch 84/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1078 - accuracy: 0.9626 - val_loss: 0.4668 - val_accuracy: 0.8368
# Epoch 85/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1207 - accuracy: 0.9514 - val_loss: 0.5030 - val_accuracy: 0.8195
# Epoch 86/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1003 - accuracy: 0.9657 - val_loss: 0.7831 - val_accuracy: 0.7565
# Epoch 87/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0920 - accuracy: 0.9657 - val_loss: 0.8086 - val_accuracy: 0.7466
# Epoch 88/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1287 - accuracy: 0.9502 - val_loss: 1.3464 - val_accuracy: 0.6761
# Epoch 89/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1087 - accuracy: 0.9579 - val_loss: 0.3797 - val_accuracy: 0.8665
# Epoch 90/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1085 - accuracy: 0.9582 - val_loss: 0.4724 - val_accuracy: 0.8356
# Epoch 91/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1106 - accuracy: 0.9564 - val_loss: 0.3764 - val_accuracy: 0.8628
# Epoch 92/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0906 - accuracy: 0.9647 - val_loss: 0.3717 - val_accuracy: 0.8529
# Epoch 93/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0945 - accuracy: 0.9641 - val_loss: 0.6796 - val_accuracy: 0.7837
# Epoch 94/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0963 - accuracy: 0.9635 - val_loss: 0.6930 - val_accuracy: 0.8072
# Epoch 95/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1031 - accuracy: 0.9626 - val_loss: 0.4653 - val_accuracy: 0.8220
# Epoch 96/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0977 - accuracy: 0.9623 - val_loss: 0.5126 - val_accuracy: 0.8578
# Epoch 97/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.0930 - accuracy: 0.9632 - val_loss: 0.5197 - val_accuracy: 0.8121
# Epoch 98/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0791 - accuracy: 0.9706 - val_loss: 0.3941 - val_accuracy: 0.8467
# Epoch 99/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.0875 - accuracy: 0.9688 - val_loss: 0.5083 - val_accuracy: 0.8232
# Epoch 100/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0937 - accuracy: 0.9638 - val_loss: 0.6140 - val_accuracy: 0.8356
# Accuracy on Fold 1: 83.56%
#
# Training on Fold 2/5...
# Epoch 1/100
# 51/51 [==============================] - 18s 245ms/step - loss: 0.8127 - accuracy: 0.5939 - val_loss: 0.7764 - val_accuracy: 0.6250
# Epoch 2/100
# 51/51 [==============================] - 9s 178ms/step - loss: 0.6776 - accuracy: 0.6675 - val_loss: 1.2953 - val_accuracy: 0.6250
# Epoch 3/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.6543 - accuracy: 0.6792 - val_loss: 2.3048 - val_accuracy: 0.6250
# Epoch 4/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.6084 - accuracy: 0.7018 - val_loss: 3.6005 - val_accuracy: 0.6250
# Epoch 5/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.6228 - accuracy: 0.7099 - val_loss: 3.7012 - val_accuracy: 0.6250
# Epoch 6/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.5758 - accuracy: 0.7204 - val_loss: 3.8432 - val_accuracy: 0.6250
# Epoch 7/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.5649 - accuracy: 0.7300 - val_loss: 3.2266 - val_accuracy: 0.6250
# Epoch 8/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.5665 - accuracy: 0.7297 - val_loss: 3.1004 - val_accuracy: 0.6250
# Epoch 9/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5275 - accuracy: 0.7575 - val_loss: 1.4593 - val_accuracy: 0.6287
# Epoch 10/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5306 - accuracy: 0.7594 - val_loss: 0.8887 - val_accuracy: 0.6658
# Epoch 11/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5070 - accuracy: 0.7643 - val_loss: 0.5916 - val_accuracy: 0.7426
# Epoch 12/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4977 - accuracy: 0.7723 - val_loss: 0.4994 - val_accuracy: 0.7661
# Epoch 13/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.4726 - accuracy: 0.7822 - val_loss: 0.5020 - val_accuracy: 0.7500
# Epoch 14/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4732 - accuracy: 0.7810 - val_loss: 0.5053 - val_accuracy: 0.7475
# Epoch 15/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4693 - accuracy: 0.7875 - val_loss: 1.6028 - val_accuracy: 0.6411
# Epoch 16/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.4643 - accuracy: 0.7872 - val_loss: 0.5308 - val_accuracy: 0.7562
# Epoch 17/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4506 - accuracy: 0.8048 - val_loss: 0.8025 - val_accuracy: 0.7129
# Epoch 18/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.4458 - accuracy: 0.8042 - val_loss: 0.4200 - val_accuracy: 0.8106
# Epoch 19/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4037 - accuracy: 0.8172 - val_loss: 0.4262 - val_accuracy: 0.8032
# Epoch 20/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4134 - accuracy: 0.8181 - val_loss: 0.4632 - val_accuracy: 0.7933
# Epoch 21/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3941 - accuracy: 0.8265 - val_loss: 0.4609 - val_accuracy: 0.7983
# Epoch 22/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3949 - accuracy: 0.8351 - val_loss: 0.4514 - val_accuracy: 0.7921
# Epoch 23/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3720 - accuracy: 0.8320 - val_loss: 0.4709 - val_accuracy: 0.7983
# Epoch 24/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3862 - accuracy: 0.8212 - val_loss: 0.4590 - val_accuracy: 0.8069
# Epoch 25/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3693 - accuracy: 0.8376 - val_loss: 0.5450 - val_accuracy: 0.7797
# Epoch 26/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3692 - accuracy: 0.8401 - val_loss: 0.4850 - val_accuracy: 0.8032
# Epoch 27/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3515 - accuracy: 0.8469 - val_loss: 0.7841 - val_accuracy: 0.6411
# Epoch 28/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3503 - accuracy: 0.8531 - val_loss: 0.7355 - val_accuracy: 0.7611
# Epoch 29/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3268 - accuracy: 0.8593 - val_loss: 0.6366 - val_accuracy: 0.7450
# Epoch 30/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3206 - accuracy: 0.8552 - val_loss: 0.5616 - val_accuracy: 0.7896
# Epoch 31/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3134 - accuracy: 0.8658 - val_loss: 0.5980 - val_accuracy: 0.7673
# Epoch 32/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3146 - accuracy: 0.8670 - val_loss: 0.4290 - val_accuracy: 0.8131
# Epoch 33/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3090 - accuracy: 0.8645 - val_loss: 0.4050 - val_accuracy: 0.8379
# Epoch 34/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2877 - accuracy: 0.8818 - val_loss: 0.4179 - val_accuracy: 0.8354
# Epoch 35/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3056 - accuracy: 0.8726 - val_loss: 0.5470 - val_accuracy: 0.7995
# Epoch 36/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2999 - accuracy: 0.8716 - val_loss: 0.5586 - val_accuracy: 0.7834
# Epoch 37/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2896 - accuracy: 0.8797 - val_loss: 1.3261 - val_accuracy: 0.5817
# Epoch 38/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2796 - accuracy: 0.8846 - val_loss: 0.4551 - val_accuracy: 0.8106
# Epoch 39/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2695 - accuracy: 0.8893 - val_loss: 0.6481 - val_accuracy: 0.7438
# Epoch 40/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2643 - accuracy: 0.8886 - val_loss: 0.5021 - val_accuracy: 0.8094
# Epoch 41/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2535 - accuracy: 0.8902 - val_loss: 0.4780 - val_accuracy: 0.8218
# Epoch 42/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2535 - accuracy: 0.8942 - val_loss: 0.3784 - val_accuracy: 0.8552
# Epoch 43/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.2474 - accuracy: 0.8951 - val_loss: 0.4087 - val_accuracy: 0.8366
# Epoch 44/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.2456 - accuracy: 0.8973 - val_loss: 0.7870 - val_accuracy: 0.7376
# Epoch 45/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2424 - accuracy: 0.9016 - val_loss: 0.5635 - val_accuracy: 0.7859
# Epoch 46/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2531 - accuracy: 0.8989 - val_loss: 0.4209 - val_accuracy: 0.8379
# Epoch 47/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2154 - accuracy: 0.9100 - val_loss: 0.5154 - val_accuracy: 0.8144
# Epoch 48/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2189 - accuracy: 0.9128 - val_loss: 0.4627 - val_accuracy: 0.8218
# Epoch 49/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2203 - accuracy: 0.9131 - val_loss: 0.3825 - val_accuracy: 0.8663
# Epoch 50/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2149 - accuracy: 0.9094 - val_loss: 0.3729 - val_accuracy: 0.8416
# Epoch 51/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1947 - accuracy: 0.9217 - val_loss: 0.4994 - val_accuracy: 0.8119
# Epoch 52/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2066 - accuracy: 0.9152 - val_loss: 0.4665 - val_accuracy: 0.8156
# Epoch 53/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1826 - accuracy: 0.9273 - val_loss: 0.5096 - val_accuracy: 0.8032
# Epoch 54/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2136 - accuracy: 0.9122 - val_loss: 0.5721 - val_accuracy: 0.7983
# Epoch 55/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2020 - accuracy: 0.9171 - val_loss: 0.5688 - val_accuracy: 0.8119
# Epoch 56/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1824 - accuracy: 0.9295 - val_loss: 0.5589 - val_accuracy: 0.7933
# Epoch 57/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2008 - accuracy: 0.9208 - val_loss: 0.4630 - val_accuracy: 0.8342
# Epoch 58/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1873 - accuracy: 0.9214 - val_loss: 0.4780 - val_accuracy: 0.8106
# Epoch 59/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1858 - accuracy: 0.9236 - val_loss: 0.4466 - val_accuracy: 0.8304
# Epoch 60/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1718 - accuracy: 0.9316 - val_loss: 0.4200 - val_accuracy: 0.8416
# Epoch 61/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1593 - accuracy: 0.9384 - val_loss: 0.4322 - val_accuracy: 0.8366
# Epoch 62/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1646 - accuracy: 0.9335 - val_loss: 0.4778 - val_accuracy: 0.8131
# Epoch 63/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1597 - accuracy: 0.9360 - val_loss: 0.8331 - val_accuracy: 0.7141
# Epoch 64/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1467 - accuracy: 0.9363 - val_loss: 0.6671 - val_accuracy: 0.7809
# Epoch 65/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1531 - accuracy: 0.9403 - val_loss: 0.6407 - val_accuracy: 0.7760
# Epoch 66/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1669 - accuracy: 0.9360 - val_loss: 0.4169 - val_accuracy: 0.8552
# Epoch 67/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1540 - accuracy: 0.9354 - val_loss: 0.3984 - val_accuracy: 0.8626
# Epoch 68/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1358 - accuracy: 0.9527 - val_loss: 0.4355 - val_accuracy: 0.8441
# Epoch 69/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1453 - accuracy: 0.9391 - val_loss: 0.3543 - val_accuracy: 0.8688
# Epoch 70/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1351 - accuracy: 0.9462 - val_loss: 0.4167 - val_accuracy: 0.8441
# Epoch 71/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1640 - accuracy: 0.9338 - val_loss: 0.6330 - val_accuracy: 0.7859
# Epoch 72/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1408 - accuracy: 0.9418 - val_loss: 0.9915 - val_accuracy: 0.7562
# Epoch 73/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1336 - accuracy: 0.9465 - val_loss: 0.5967 - val_accuracy: 0.8267
# Epoch 74/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1397 - accuracy: 0.9487 - val_loss: 0.4955 - val_accuracy: 0.8243
# Epoch 75/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1310 - accuracy: 0.9490 - val_loss: 0.4001 - val_accuracy: 0.8577
# Epoch 76/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1119 - accuracy: 0.9545 - val_loss: 0.7021 - val_accuracy: 0.7933
# Epoch 77/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1271 - accuracy: 0.9536 - val_loss: 0.6509 - val_accuracy: 0.8267
# Epoch 78/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1232 - accuracy: 0.9521 - val_loss: 0.5246 - val_accuracy: 0.8255
# Epoch 79/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1203 - accuracy: 0.9527 - val_loss: 0.6838 - val_accuracy: 0.7908
# Epoch 80/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1130 - accuracy: 0.9564 - val_loss: 0.7348 - val_accuracy: 0.7958
# Epoch 81/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1112 - accuracy: 0.9626 - val_loss: 0.4072 - val_accuracy: 0.8502
# Epoch 82/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0971 - accuracy: 0.9604 - val_loss: 0.5886 - val_accuracy: 0.8119
# Epoch 83/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0954 - accuracy: 0.9610 - val_loss: 0.5882 - val_accuracy: 0.7834
# Epoch 84/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1148 - accuracy: 0.9530 - val_loss: 0.5793 - val_accuracy: 0.8193
# Epoch 85/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1224 - accuracy: 0.9536 - val_loss: 0.5037 - val_accuracy: 0.8453
# Epoch 86/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1078 - accuracy: 0.9589 - val_loss: 0.4383 - val_accuracy: 0.8552
# Epoch 87/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1176 - accuracy: 0.9552 - val_loss: 0.5295 - val_accuracy: 0.8366
# Epoch 88/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1037 - accuracy: 0.9616 - val_loss: 0.4932 - val_accuracy: 0.8379
# Epoch 89/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1111 - accuracy: 0.9616 - val_loss: 0.3982 - val_accuracy: 0.8614
# Epoch 90/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1060 - accuracy: 0.9567 - val_loss: 0.4488 - val_accuracy: 0.8453
# Epoch 91/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0974 - accuracy: 0.9601 - val_loss: 1.0349 - val_accuracy: 0.7166
# Epoch 92/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0995 - accuracy: 0.9641 - val_loss: 0.4730 - val_accuracy: 0.8552
# Epoch 93/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0956 - accuracy: 0.9635 - val_loss: 0.6942 - val_accuracy: 0.7995
# Epoch 94/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0794 - accuracy: 0.9731 - val_loss: 0.6811 - val_accuracy: 0.8045
# Epoch 95/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1208 - accuracy: 0.9564 - val_loss: 0.7488 - val_accuracy: 0.7611
# Epoch 96/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0799 - accuracy: 0.9685 - val_loss: 0.4143 - val_accuracy: 0.8428
# Epoch 97/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.0877 - accuracy: 0.9657 - val_loss: 0.5080 - val_accuracy: 0.8416
# Epoch 98/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0776 - accuracy: 0.9691 - val_loss: 0.6254 - val_accuracy: 0.8045
# Epoch 99/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.0756 - accuracy: 0.9737 - val_loss: 0.4126 - val_accuracy: 0.8676
# Epoch 100/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0685 - accuracy: 0.9780 - val_loss: 0.4360 - val_accuracy: 0.8663
# Accuracy on Fold 2: 86.63%
#
# Training on Fold 3/5...
# Epoch 1/100
# 51/51 [==============================] - 15s 180ms/step - loss: 0.8353 - accuracy: 0.6041 - val_loss: 0.8888 - val_accuracy: 0.6250
# Epoch 2/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.6783 - accuracy: 0.6724 - val_loss: 2.1842 - val_accuracy: 0.6250
# Epoch 3/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.6237 - accuracy: 0.7024 - val_loss: 3.2317 - val_accuracy: 0.6250
# Epoch 4/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.5929 - accuracy: 0.7136 - val_loss: 3.7866 - val_accuracy: 0.6250
# Epoch 5/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5889 - accuracy: 0.7173 - val_loss: 4.2454 - val_accuracy: 0.6250
# Epoch 6/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.5495 - accuracy: 0.7405 - val_loss: 3.9315 - val_accuracy: 0.6250
# Epoch 7/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.5422 - accuracy: 0.7590 - val_loss: 4.0148 - val_accuracy: 0.6250
# Epoch 8/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.5351 - accuracy: 0.7501 - val_loss: 3.4917 - val_accuracy: 0.6250
# Epoch 9/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.5129 - accuracy: 0.7699 - val_loss: 2.9898 - val_accuracy: 0.6262
# Epoch 10/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5081 - accuracy: 0.7659 - val_loss: 2.2063 - val_accuracy: 0.6262
# Epoch 11/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4924 - accuracy: 0.7776 - val_loss: 1.1947 - val_accuracy: 0.6559
# Epoch 12/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4948 - accuracy: 0.7795 - val_loss: 0.5889 - val_accuracy: 0.7413
# Epoch 13/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4769 - accuracy: 0.7989 - val_loss: 0.5771 - val_accuracy: 0.7710
# Epoch 14/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.4585 - accuracy: 0.7946 - val_loss: 0.4795 - val_accuracy: 0.7871
# Epoch 15/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.4550 - accuracy: 0.7959 - val_loss: 0.5914 - val_accuracy: 0.7413
# Epoch 16/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4554 - accuracy: 0.7980 - val_loss: 0.5151 - val_accuracy: 0.7735
# Epoch 17/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4351 - accuracy: 0.8002 - val_loss: 0.6073 - val_accuracy: 0.7562
# Epoch 18/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4288 - accuracy: 0.7999 - val_loss: 0.8770 - val_accuracy: 0.6832
# Epoch 19/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3977 - accuracy: 0.8324 - val_loss: 0.3951 - val_accuracy: 0.8230
# Epoch 20/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3965 - accuracy: 0.8135 - val_loss: 0.6533 - val_accuracy: 0.7413
# Epoch 21/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3828 - accuracy: 0.8342 - val_loss: 0.6659 - val_accuracy: 0.6881
# Epoch 22/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3960 - accuracy: 0.8358 - val_loss: 0.3969 - val_accuracy: 0.8131
# Epoch 23/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3939 - accuracy: 0.8243 - val_loss: 0.4471 - val_accuracy: 0.8094
# Epoch 24/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3723 - accuracy: 0.8478 - val_loss: 0.4948 - val_accuracy: 0.7983
# Epoch 25/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.3615 - accuracy: 0.8388 - val_loss: 0.4903 - val_accuracy: 0.7710
# Epoch 26/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3562 - accuracy: 0.8478 - val_loss: 1.6694 - val_accuracy: 0.6089
# Epoch 27/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3632 - accuracy: 0.8552 - val_loss: 0.6803 - val_accuracy: 0.7450
# Epoch 28/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3580 - accuracy: 0.8432 - val_loss: 0.7356 - val_accuracy: 0.7092
# Epoch 29/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3357 - accuracy: 0.8617 - val_loss: 0.9963 - val_accuracy: 0.6473
# Epoch 30/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3299 - accuracy: 0.8586 - val_loss: 0.4112 - val_accuracy: 0.8131
# Epoch 31/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3100 - accuracy: 0.8667 - val_loss: 0.5471 - val_accuracy: 0.7587
# Epoch 32/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3232 - accuracy: 0.8611 - val_loss: 0.8002 - val_accuracy: 0.7067
# Epoch 33/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3254 - accuracy: 0.8627 - val_loss: 0.7912 - val_accuracy: 0.6844
# Epoch 34/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3212 - accuracy: 0.8732 - val_loss: 1.1892 - val_accuracy: 0.6163
# Epoch 35/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.2963 - accuracy: 0.8806 - val_loss: 0.4635 - val_accuracy: 0.8181
# Epoch 36/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2816 - accuracy: 0.8843 - val_loss: 0.7153 - val_accuracy: 0.7116
# Epoch 37/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2990 - accuracy: 0.8784 - val_loss: 0.4509 - val_accuracy: 0.7958
# Epoch 38/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2815 - accuracy: 0.8868 - val_loss: 0.4392 - val_accuracy: 0.8106
# Epoch 39/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2896 - accuracy: 0.8803 - val_loss: 0.3830 - val_accuracy: 0.8304
# Epoch 40/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2740 - accuracy: 0.8880 - val_loss: 0.6828 - val_accuracy: 0.7735
# Epoch 41/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2531 - accuracy: 0.8877 - val_loss: 0.5623 - val_accuracy: 0.7500
# Epoch 42/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2455 - accuracy: 0.9038 - val_loss: 0.4516 - val_accuracy: 0.7921
# Epoch 43/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2497 - accuracy: 0.9001 - val_loss: 0.4584 - val_accuracy: 0.8032
# Epoch 44/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2528 - accuracy: 0.8936 - val_loss: 0.4188 - val_accuracy: 0.8527
# Epoch 45/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2378 - accuracy: 0.9112 - val_loss: 0.4169 - val_accuracy: 0.8230
# Epoch 46/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2329 - accuracy: 0.9103 - val_loss: 0.4661 - val_accuracy: 0.8168
# Epoch 47/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2295 - accuracy: 0.9075 - val_loss: 0.8370 - val_accuracy: 0.7141
# Epoch 48/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2187 - accuracy: 0.9112 - val_loss: 1.8122 - val_accuracy: 0.5285
# Epoch 49/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2250 - accuracy: 0.9094 - val_loss: 0.5206 - val_accuracy: 0.7921
# Epoch 50/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2109 - accuracy: 0.9156 - val_loss: 0.7282 - val_accuracy: 0.7661
# Epoch 51/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2053 - accuracy: 0.9211 - val_loss: 0.5128 - val_accuracy: 0.7859
# Epoch 52/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.2087 - accuracy: 0.9168 - val_loss: 0.5456 - val_accuracy: 0.7884
# Epoch 53/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2140 - accuracy: 0.9143 - val_loss: 0.4156 - val_accuracy: 0.8342
# Epoch 54/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1805 - accuracy: 0.9276 - val_loss: 0.4173 - val_accuracy: 0.8403
# Epoch 55/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1935 - accuracy: 0.9211 - val_loss: 0.6953 - val_accuracy: 0.7389
# Epoch 56/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1868 - accuracy: 0.9248 - val_loss: 1.3574 - val_accuracy: 0.5755
# Epoch 57/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1903 - accuracy: 0.9217 - val_loss: 0.8192 - val_accuracy: 0.7525
# Epoch 58/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1919 - accuracy: 0.9224 - val_loss: 0.8805 - val_accuracy: 0.7054
# Epoch 59/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1720 - accuracy: 0.9298 - val_loss: 0.4298 - val_accuracy: 0.8366
# Epoch 60/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1656 - accuracy: 0.9341 - val_loss: 0.3915 - val_accuracy: 0.8441
# Epoch 61/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1705 - accuracy: 0.9338 - val_loss: 0.6966 - val_accuracy: 0.7599
# Epoch 62/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1695 - accuracy: 0.9338 - val_loss: 0.8843 - val_accuracy: 0.7141
# Epoch 63/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1539 - accuracy: 0.9422 - val_loss: 0.4640 - val_accuracy: 0.8280
# Epoch 64/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1825 - accuracy: 0.9298 - val_loss: 0.4312 - val_accuracy: 0.8366
# Epoch 65/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1507 - accuracy: 0.9418 - val_loss: 0.6636 - val_accuracy: 0.7933
# Epoch 66/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1499 - accuracy: 0.9440 - val_loss: 0.5331 - val_accuracy: 0.8032
# Epoch 67/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1421 - accuracy: 0.9418 - val_loss: 0.4376 - val_accuracy: 0.8292
# Epoch 68/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1346 - accuracy: 0.9471 - val_loss: 0.5014 - val_accuracy: 0.8230
# Epoch 69/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1449 - accuracy: 0.9422 - val_loss: 0.3659 - val_accuracy: 0.8775
# Epoch 70/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.1356 - accuracy: 0.9446 - val_loss: 0.6519 - val_accuracy: 0.7710
# Epoch 71/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1372 - accuracy: 0.9477 - val_loss: 0.4721 - val_accuracy: 0.8441
# Epoch 72/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1310 - accuracy: 0.9496 - val_loss: 0.4989 - val_accuracy: 0.8403
# Epoch 73/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1398 - accuracy: 0.9493 - val_loss: 0.5396 - val_accuracy: 0.8094
# Epoch 74/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1170 - accuracy: 0.9530 - val_loss: 0.4506 - val_accuracy: 0.8304
# Epoch 75/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0997 - accuracy: 0.9623 - val_loss: 0.4615 - val_accuracy: 0.8205
# Epoch 76/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1084 - accuracy: 0.9595 - val_loss: 0.9893 - val_accuracy: 0.7760
# Epoch 77/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1093 - accuracy: 0.9626 - val_loss: 2.8184 - val_accuracy: 0.5074
# Epoch 78/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1363 - accuracy: 0.9459 - val_loss: 0.4826 - val_accuracy: 0.8243
# Epoch 79/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1026 - accuracy: 0.9623 - val_loss: 0.4472 - val_accuracy: 0.8391
# Epoch 80/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1115 - accuracy: 0.9579 - val_loss: 0.4222 - val_accuracy: 0.8366
# Epoch 81/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0954 - accuracy: 0.9626 - val_loss: 0.8892 - val_accuracy: 0.7339
# Epoch 82/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1122 - accuracy: 0.9570 - val_loss: 0.5619 - val_accuracy: 0.8366
# Epoch 83/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.1061 - accuracy: 0.9604 - val_loss: 0.9923 - val_accuracy: 0.7178
# Epoch 84/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1053 - accuracy: 0.9616 - val_loss: 0.5978 - val_accuracy: 0.8069
# Epoch 85/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1075 - accuracy: 0.9616 - val_loss: 0.6664 - val_accuracy: 0.8045
# Epoch 86/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1164 - accuracy: 0.9542 - val_loss: 0.4752 - val_accuracy: 0.8342
# Epoch 87/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0869 - accuracy: 0.9697 - val_loss: 0.7462 - val_accuracy: 0.8020
# Epoch 88/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0885 - accuracy: 0.9675 - val_loss: 0.4681 - val_accuracy: 0.8379
# Epoch 89/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0850 - accuracy: 0.9691 - val_loss: 0.5542 - val_accuracy: 0.8181
# Epoch 90/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0729 - accuracy: 0.9749 - val_loss: 1.0289 - val_accuracy: 0.7624
# Epoch 91/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0712 - accuracy: 0.9753 - val_loss: 0.4397 - val_accuracy: 0.8601
# Epoch 92/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0894 - accuracy: 0.9657 - val_loss: 0.5263 - val_accuracy: 0.8267
# Epoch 93/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0825 - accuracy: 0.9706 - val_loss: 1.0256 - val_accuracy: 0.7314
# Epoch 94/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0842 - accuracy: 0.9675 - val_loss: 0.4393 - val_accuracy: 0.8589
# Epoch 95/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0892 - accuracy: 0.9650 - val_loss: 0.5646 - val_accuracy: 0.8304
# Epoch 96/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0937 - accuracy: 0.9629 - val_loss: 1.0179 - val_accuracy: 0.7339
# Epoch 97/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0777 - accuracy: 0.9694 - val_loss: 0.7575 - val_accuracy: 0.7983
# Epoch 98/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0802 - accuracy: 0.9706 - val_loss: 0.4814 - val_accuracy: 0.8478
# Epoch 99/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0858 - accuracy: 0.9688 - val_loss: 0.6414 - val_accuracy: 0.7995
# Epoch 100/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0827 - accuracy: 0.9654 - val_loss: 0.5516 - val_accuracy: 0.8045
# Accuracy on Fold 3: 80.45%
#
# Training on Fold 4/5...
# Epoch 1/100
# 51/51 [==============================] - 15s 198ms/step - loss: 0.8030 - accuracy: 0.6328 - val_loss: 1.5639 - val_accuracy: 0.6250
# Epoch 2/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.6813 - accuracy: 0.6842 - val_loss: 2.4504 - val_accuracy: 0.6250
# Epoch 3/100
# 51/51 [==============================] - 9s 179ms/step - loss: 0.6378 - accuracy: 0.6947 - val_loss: 3.7925 - val_accuracy: 0.6250
# Epoch 4/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.6153 - accuracy: 0.7055 - val_loss: 3.8406 - val_accuracy: 0.6250
# Epoch 5/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.5905 - accuracy: 0.7229 - val_loss: 5.4477 - val_accuracy: 0.6250
# Epoch 6/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.5654 - accuracy: 0.7275 - val_loss: 5.5299 - val_accuracy: 0.6250
# Epoch 7/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.5465 - accuracy: 0.7408 - val_loss: 5.3646 - val_accuracy: 0.6250
# Epoch 8/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.5147 - accuracy: 0.7671 - val_loss: 3.3769 - val_accuracy: 0.6250
# Epoch 9/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.5165 - accuracy: 0.7606 - val_loss: 3.3964 - val_accuracy: 0.6250
# Epoch 10/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5280 - accuracy: 0.7578 - val_loss: 1.4407 - val_accuracy: 0.6287
# Epoch 11/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.5030 - accuracy: 0.7671 - val_loss: 1.0876 - val_accuracy: 0.6584
# Epoch 12/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.4874 - accuracy: 0.7745 - val_loss: 0.5187 - val_accuracy: 0.7723
# Epoch 13/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4712 - accuracy: 0.7798 - val_loss: 0.5001 - val_accuracy: 0.7525
# Epoch 14/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4694 - accuracy: 0.7881 - val_loss: 0.5028 - val_accuracy: 0.7661
# Epoch 15/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4261 - accuracy: 0.8079 - val_loss: 0.8251 - val_accuracy: 0.7079
# Epoch 16/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4324 - accuracy: 0.8045 - val_loss: 0.5269 - val_accuracy: 0.7686
# Epoch 17/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4309 - accuracy: 0.7974 - val_loss: 0.4126 - val_accuracy: 0.8144
# Epoch 18/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4228 - accuracy: 0.8104 - val_loss: 0.5194 - val_accuracy: 0.7574
# Epoch 19/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4092 - accuracy: 0.8212 - val_loss: 0.5892 - val_accuracy: 0.7413
# Epoch 20/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.4046 - accuracy: 0.8132 - val_loss: 0.4165 - val_accuracy: 0.8069
# Epoch 21/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3701 - accuracy: 0.8345 - val_loss: 0.4391 - val_accuracy: 0.8106
# Epoch 22/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3745 - accuracy: 0.8404 - val_loss: 0.3632 - val_accuracy: 0.8403
# Epoch 23/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3667 - accuracy: 0.8401 - val_loss: 0.6461 - val_accuracy: 0.7488
# Epoch 24/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3481 - accuracy: 0.8518 - val_loss: 0.3820 - val_accuracy: 0.8379
# Epoch 25/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3569 - accuracy: 0.8484 - val_loss: 0.4120 - val_accuracy: 0.8020
# Epoch 26/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3293 - accuracy: 0.8602 - val_loss: 0.3928 - val_accuracy: 0.8267
# Epoch 27/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3408 - accuracy: 0.8481 - val_loss: 0.3673 - val_accuracy: 0.8403
# Epoch 28/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3149 - accuracy: 0.8682 - val_loss: 0.8960 - val_accuracy: 0.6584
# Epoch 29/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.3181 - accuracy: 0.8661 - val_loss: 0.4904 - val_accuracy: 0.7562
# Epoch 30/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3287 - accuracy: 0.8664 - val_loss: 0.4343 - val_accuracy: 0.8243
# Epoch 31/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3018 - accuracy: 0.8726 - val_loss: 0.3615 - val_accuracy: 0.8403
# Epoch 32/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.3076 - accuracy: 0.8692 - val_loss: 0.5691 - val_accuracy: 0.7376
# Epoch 33/100
# ...
# Epoch 91/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1048 - accuracy: 0.9592 - val_loss: 0.5346 - val_accuracy: 0.8317
# Epoch 92/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0925 - accuracy: 0.9663 - val_loss: 0.3994 - val_accuracy: 0.8577
# Epoch 93/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0974 - accuracy: 0.9632 - val_loss: 0.5170 - val_accuracy: 0.8515
# Epoch 94/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0945 - accuracy: 0.9654 - val_loss: 0.7215 - val_accuracy: 0.8193
# Epoch 95/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0918 - accuracy: 0.9641 - val_loss: 0.5991 - val_accuracy: 0.8205
# Epoch 96/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0790 - accuracy: 0.9700 - val_loss: 0.7596 - val_accuracy: 0.7859
# Epoch 97/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0792 - accuracy: 0.9700 - val_loss: 0.5366 - val_accuracy: 0.8416
# Epoch 98/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0911 - accuracy: 0.9644 - val_loss: 0.6848 - val_accuracy: 0.8106
# Epoch 99/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0815 - accuracy: 0.9712 - val_loss: 0.8376 - val_accuracy: 0.7847
# Epoch 100/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0791 - accuracy: 0.9728 - val_loss: 0.3967 - val_accuracy: 0.8738
# Accuracy on Fold 4: 87.38%
#
# Training on Fold 5/5...
# Epoch 1/100
# 51/51 [==============================] - 15s 180ms/step - loss: 0.8174 - accuracy: 0.5939 - val_loss: 0.9781 - val_accuracy: 0.6262
# Epoch 2/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.7124 - accuracy: 0.6502 - val_loss: 2.2108 - val_accuracy: 0.6262
# Epoch 3/100
# 51/51 [==============================] - 9s 176ms/step - loss: 0.6682 - accuracy: 0.6820 - val_loss: 2.5230 - val_accuracy: 0.6262
# Epoch 4/100
# 51/51 [==============================] - 9s 177ms/step - loss: 0.5998 - accuracy: 0.7074 - val_loss: 3.5113 - val_accuracy: 0.6262
# Epoch 5/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.6179 - accuracy: 0.6981 - val_loss: 3.7007 - val_accuracy: 0.6262
# Epoch 6/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5983 - accuracy: 0.7170 - val_loss: 4.3067 - val_accuracy: 0.6262
# Epoch 7/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.5876 - accuracy: 0.7309 - val_loss: 3.9930 - val_accuracy: 0.6262
# Epoch 8/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5476 - accuracy: 0.7365 - val_loss: 3.2812 - val_accuracy: 0.6262
# Epoch 9/100
# 51/51 [==============================] - 9s 169ms/step - loss: 0.5484 - accuracy: 0.7436 - val_loss: 2.3313 - val_accuracy: 0.6275
# Epoch 10/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5471 - accuracy: 0.7423 - val_loss: 1.1989 - val_accuracy: 0.6374
# Epoch 11/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.5144 - accuracy: 0.7693 - val_loss: 0.7419 - val_accuracy: 0.7042
# Epoch 12/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.4947 - accuracy: 0.7711 - val_loss: 0.5446 - val_accuracy: 0.7525
# Epoch 13/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.4852 - accuracy: 0.7822 - val_loss: 0.6529 - val_accuracy: 0.7389
# Epoch 14/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4881 - accuracy: 0.7773 - val_loss: 0.4308 - val_accuracy: 0.8106
# Epoch 15/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4738 - accuracy: 0.7897 - val_loss: 0.5068 - val_accuracy: 0.7698
# Epoch 16/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4588 - accuracy: 0.7884 - val_loss: 0.5048 - val_accuracy: 0.7636
# Epoch 17/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.4304 - accuracy: 0.8092 - val_loss: 1.0249 - val_accuracy: 0.6634
# Epoch 18/100
# 51/51 [==============================] - 9s 170ms/step - loss: 0.4461 - accuracy: 0.7980 - val_loss: 0.6077 - val_accuracy: 0.7574
# Epoch 19/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.4239 - accuracy: 0.8153 - val_loss: 0.4475 - val_accuracy: 0.8106
# Epoch 20/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.4062 - accuracy: 0.8197 - val_loss: 0.6672 - val_accuracy: 0.7401
# Epoch 21/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.4122 - accuracy: 0.8147 - val_loss: 0.7350 - val_accuracy: 0.7153
# Epoch 22/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3982 - accuracy: 0.8203 - val_loss: 0.5565 - val_accuracy: 0.7438
# Epoch 23/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3835 - accuracy: 0.8364 - val_loss: 0.4376 - val_accuracy: 0.8168
# Epoch 24/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3806 - accuracy: 0.8277 - val_loss: 0.4749 - val_accuracy: 0.8007
# Epoch 25/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3602 - accuracy: 0.8401 - val_loss: 0.4601 - val_accuracy: 0.8106
# Epoch 26/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3597 - accuracy: 0.8404 - val_loss: 0.9000 - val_accuracy: 0.7030
# Epoch 27/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3424 - accuracy: 0.8565 - val_loss: 0.4984 - val_accuracy: 0.7822
# Epoch 28/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.3565 - accuracy: 0.8475 - val_loss: 0.5233 - val_accuracy: 0.7698
# Epoch 29/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.3313 - accuracy: 0.8620 - val_loss: 0.7355 - val_accuracy: 0.7426
# Epoch 30/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.3305 - accuracy: 0.8624 - val_loss: 0.6227 - val_accuracy: 0.7587
# Epoch 31/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.3002 - accuracy: 0.8704 - val_loss: 0.5224 - val_accuracy: 0.7847
# Epoch 32/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.3308 - accuracy: 0.8624 - val_loss: 0.7202 - val_accuracy: 0.7364
# Epoch 33/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2891 - accuracy: 0.8788 - val_loss: 0.3666 - val_accuracy: 0.8527
# Epoch 34/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.3038 - accuracy: 0.8692 - val_loss: 0.5660 - val_accuracy: 0.7525
# Epoch 35/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.3023 - accuracy: 0.8710 - val_loss: 0.3605 - val_accuracy: 0.8589
# Epoch 36/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.2907 - accuracy: 0.8747 - val_loss: 0.5439 - val_accuracy: 0.8032
# Epoch 37/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2863 - accuracy: 0.8781 - val_loss: 0.5069 - val_accuracy: 0.7995
# Epoch 38/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.2766 - accuracy: 0.8852 - val_loss: 0.4927 - val_accuracy: 0.7847
# Epoch 39/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2776 - accuracy: 0.8837 - val_loss: 0.8989 - val_accuracy: 0.7401
# Epoch 40/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2699 - accuracy: 0.8815 - val_loss: 0.5404 - val_accuracy: 0.8094
# Epoch 41/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2508 - accuracy: 0.8958 - val_loss: 0.6186 - val_accuracy: 0.7896
# Epoch 42/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2614 - accuracy: 0.8917 - val_loss: 0.6297 - val_accuracy: 0.7822
# Epoch 43/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.2492 - accuracy: 0.9007 - val_loss: 0.4634 - val_accuracy: 0.8255
# Epoch 44/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2436 - accuracy: 0.8992 - val_loss: 0.5053 - val_accuracy: 0.7958
# Epoch 45/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2388 - accuracy: 0.9023 - val_loss: 0.4527 - val_accuracy: 0.8280
# Epoch 46/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.2197 - accuracy: 0.9115 - val_loss: 0.7847 - val_accuracy: 0.7327
# Epoch 47/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.2280 - accuracy: 0.9054 - val_loss: 0.4435 - val_accuracy: 0.8255
# Epoch 48/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2232 - accuracy: 0.9050 - val_loss: 0.5279 - val_accuracy: 0.8119
# Epoch 49/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2092 - accuracy: 0.9193 - val_loss: 0.4200 - val_accuracy: 0.8280
# Epoch 50/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2165 - accuracy: 0.9097 - val_loss: 0.4157 - val_accuracy: 0.8280
# Epoch 51/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2111 - accuracy: 0.9168 - val_loss: 0.5388 - val_accuracy: 0.8218
# Epoch 52/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2200 - accuracy: 0.9134 - val_loss: 0.4576 - val_accuracy: 0.8045
# Epoch 53/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.2034 - accuracy: 0.9115 - val_loss: 0.9253 - val_accuracy: 0.7525
# Epoch 54/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.2085 - accuracy: 0.9152 - val_loss: 0.4500 - val_accuracy: 0.8329
# Epoch 55/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1989 - accuracy: 0.9214 - val_loss: 0.4639 - val_accuracy: 0.8304
# Epoch 56/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1937 - accuracy: 0.9217 - val_loss: 0.6714 - val_accuracy: 0.7809
# Epoch 57/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1919 - accuracy: 0.9196 - val_loss: 0.5331 - val_accuracy: 0.8168
# Epoch 58/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1968 - accuracy: 0.9208 - val_loss: 0.4406 - val_accuracy: 0.8181
# Epoch 59/100
# 51/51 [==============================] - 9s 182ms/step - loss: 0.1928 - accuracy: 0.9230 - val_loss: 0.4958 - val_accuracy: 0.7933
# Epoch 60/100
# 51/51 [==============================] - 9s 182ms/step - loss: 0.1865 - accuracy: 0.9255 - val_loss: 0.4025 - val_accuracy: 0.8441
# Epoch 61/100
# 51/51 [==============================] - 10s 193ms/step - loss: 0.1658 - accuracy: 0.9369 - val_loss: 0.4913 - val_accuracy: 0.8020
# Epoch 62/100
# 51/51 [==============================] - 9s 180ms/step - loss: 0.1716 - accuracy: 0.9320 - val_loss: 0.4341 - val_accuracy: 0.8255
# Epoch 63/100
# 51/51 [==============================] - 9s 181ms/step - loss: 0.1824 - accuracy: 0.9276 - val_loss: 0.3864 - val_accuracy: 0.8478
# Epoch 64/100
# 51/51 [==============================] - 9s 178ms/step - loss: 0.1677 - accuracy: 0.9316 - val_loss: 1.0946 - val_accuracy: 0.7500
# Epoch 65/100
# 51/51 [==============================] - 9s 180ms/step - loss: 0.1502 - accuracy: 0.9425 - val_loss: 0.4954 - val_accuracy: 0.8007
# Epoch 66/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1596 - accuracy: 0.9381 - val_loss: 0.4641 - val_accuracy: 0.8441
# Epoch 67/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1402 - accuracy: 0.9437 - val_loss: 0.3470 - val_accuracy: 0.8750
# Epoch 68/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.1387 - accuracy: 0.9443 - val_loss: 0.4546 - val_accuracy: 0.8490
# Epoch 69/100
# 51/51 [==============================] - 9s 176ms/step - loss: 0.1553 - accuracy: 0.9360 - val_loss: 1.0309 - val_accuracy: 0.7290
# Epoch 70/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1443 - accuracy: 0.9428 - val_loss: 0.3775 - val_accuracy: 0.8577
# Epoch 71/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.1357 - accuracy: 0.9431 - val_loss: 0.4858 - val_accuracy: 0.8676
# Epoch 72/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1532 - accuracy: 0.9418 - val_loss: 0.8646 - val_accuracy: 0.7772
# Epoch 73/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1638 - accuracy: 0.9384 - val_loss: 0.5411 - val_accuracy: 0.8106
# Epoch 74/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1443 - accuracy: 0.9440 - val_loss: 0.4832 - val_accuracy: 0.8403
# Epoch 75/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1303 - accuracy: 0.9480 - val_loss: 0.4757 - val_accuracy: 0.8354
# Epoch 76/100
# 51/51 [==============================] - 9s 176ms/step - loss: 0.1241 - accuracy: 0.9527 - val_loss: 0.4590 - val_accuracy: 0.8502
# Epoch 77/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1643 - accuracy: 0.9388 - val_loss: 0.5084 - val_accuracy: 0.8453
# Epoch 78/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1402 - accuracy: 0.9459 - val_loss: 0.6712 - val_accuracy: 0.7450
# Epoch 79/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1250 - accuracy: 0.9539 - val_loss: 0.4988 - val_accuracy: 0.8230
# Epoch 80/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1181 - accuracy: 0.9539 - val_loss: 0.3784 - val_accuracy: 0.8589
# Epoch 81/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.1250 - accuracy: 0.9561 - val_loss: 0.6194 - val_accuracy: 0.8057
# Epoch 82/100
# 51/51 [==============================] - 9s 178ms/step - loss: 0.1211 - accuracy: 0.9548 - val_loss: 0.4749 - val_accuracy: 0.8478
# Epoch 83/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1097 - accuracy: 0.9601 - val_loss: 0.5037 - val_accuracy: 0.8280
# Epoch 84/100
# 51/51 [==============================] - 9s 175ms/step - loss: 0.0921 - accuracy: 0.9647 - val_loss: 0.4748 - val_accuracy: 0.8502
# Epoch 85/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0965 - accuracy: 0.9691 - val_loss: 0.4853 - val_accuracy: 0.8354
# Epoch 86/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.1101 - accuracy: 0.9573 - val_loss: 0.5874 - val_accuracy: 0.8156
# Epoch 87/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0882 - accuracy: 0.9647 - val_loss: 0.6264 - val_accuracy: 0.8156
# Epoch 88/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0912 - accuracy: 0.9638 - val_loss: 0.6530 - val_accuracy: 0.8082
# Epoch 89/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.1239 - accuracy: 0.9536 - val_loss: 0.5841 - val_accuracy: 0.8366
# Epoch 90/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.1007 - accuracy: 0.9623 - val_loss: 0.5491 - val_accuracy: 0.8267
# Epoch 91/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0890 - accuracy: 0.9669 - val_loss: 0.5358 - val_accuracy: 0.8416
# Epoch 92/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0892 - accuracy: 0.9663 - val_loss: 1.0707 - val_accuracy: 0.7760
# Epoch 93/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0904 - accuracy: 0.9647 - val_loss: 0.5419 - val_accuracy: 0.8205
# Epoch 94/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0957 - accuracy: 0.9638 - val_loss: 0.5436 - val_accuracy: 0.8205
# Epoch 95/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0872 - accuracy: 0.9700 - val_loss: 0.5047 - val_accuracy: 0.8317
# Epoch 96/100
# 51/51 [==============================] - 9s 171ms/step - loss: 0.0864 - accuracy: 0.9654 - val_loss: 0.4351 - val_accuracy: 0.8490
# Epoch 97/100
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0991 - accuracy: 0.9654 - val_loss: 0.4730 - val_accuracy: 0.8552
# Epoch 98/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0893 - accuracy: 0.9681 - val_loss: 0.5488 - val_accuracy: 0.8478
# Epoch 99/100
# 51/51 [==============================] - 9s 173ms/step - loss: 0.0962 - accuracy: 0.9620 - val_loss: 0.4383 - val_accuracy: 0.8577
# Epoch 100/100
# 51/51 [==============================] - 9s 172ms/step - loss: 0.0936 - accuracy: 0.9641 - val_loss: 0.8703 - val_accuracy: 0.7983
# Accuracy on Fold 5: 79.83%
#
# Average Accuracy Across 5 Folds: 83.57%

# %%
# Find the epoch with the highest validation accuracy
best_epoch = np.argmax(history.history['val_accuracy'])

# Plot training and validation performance metrics
plt.figure(figsize=(20, 5))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=3)
plt.plot(history.history['val_loss'], label='Validation', alpha=0.8, color='#4D61E2', linewidth=3)
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=0.3)

plt.figure(figsize=(20, 5))

# Plot training and validation accuracy, highlighting the best epoch
plt.plot(history.history['accuracy'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=3)
plt.plot(history.history['val_accuracy'], label='Validation', alpha=0.8, color='#4D61E2', linewidth=3)
plt.plot(best_epoch, history.history['val_accuracy'][best_epoch], marker='*', alpha=0.8, markersize=10, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=0.3)

plt.show()

# %%
best_epoch
# Out:
# 66

# %%
# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)
# Out:
# Predictions Shape: (499, 1)

# %%
binary_predictions = np.round(predictions)
print(binary_predictions)
# Compute the confusion matrix
cm = confusion_matrix(Y_test, binary_predictions)

# Compute classification metrics
accuracy = accuracy_score(Y_test, binary_predictions)
precision = precision_score(Y_test, binary_predictions)
recall = recall_score(Y_test, binary_predictions)
f1 = f1_score(Y_test, binary_predictions)

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
model.save('VGG16_New_Submission.keras')
model.save('Submission4(VGG16_New_Submission)')
